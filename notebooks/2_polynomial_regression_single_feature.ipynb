# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/zuu crew scores.csv")
df
# Out:
#                          MemberName  EducationLevel  Attendance  TotalHours  \
# 0             Theekshana Rathnayake               3        79.9        43.7
# 1    Mayura Sandakalum Sellapperuma               2        76.8        95.6
# 2                   Amila Narangoda               3        96.6        75.9
# 3                      Nisal Gamage               1        74.5        63.9
# 4                  Tharusha Vihanga               2        83.2        24.0
# ..                              ...             ...         ...         ...
# 145                     Student_146               3        83.9        13.3
# 146                     Student_147               3        73.4        64.9
# 147                     Student_148               3        90.8        55.2
# 148                     Student_149               2        64.3        14.6
# 149                     Student_150               1        63.0        35.1
#
# ...
